# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""

import pandas as pd

inputfile = 'Jay.txt'
jay_raw = pd.read_csv(inputfile, encoding = 'utf-8', header = None,
                      error_bad_lines = False)
                      
"""
清洗原始数据重复
"""

l_raw  = len(jay_raw)

outputfile = 'jay_clean.txt'
jay_cleaned = pd.DataFrame(jay_raw[0].unique())

l_cleaned = len(jay_cleaned)

deleted = (l_raw - l_cleaned)

jay_cleaned.to_csv(outputfile, index=False, header=False, encoding='utf-8')
# Out:
# b'Skipping line 1123: expected 1 fields, saw 2\nSkipping line 1125: expected 1 fields, saw 3\n'

# %%
jay_raw
# Out:
#                                                  0
# 0                                        ﻿怎么隐藏我的悲伤
# 1                                           失去你的地方
# 2                                         你的发香散得匆忙
# 3                                           我已经跟不上
# 4                                         闭上眼睛还能看见
# 5                                           你离去的痕迹
# 6                                         在月光下一直找寻
# 7                                           那想念的身影
# 8                                      如果说分手是苦痛的起点
# 9                                    那在终点之前我愿意再爱一遍
# 10                                     想要对你说的不敢说的爱
# 11                                       会不会有人可以明白
# 12                                      我会发着呆然后忘记你
# 13                                         接着紧紧闭上眼
# 14                                      想着那一天会有人代替
# 15                                         让我不再想念你
# 16                                      我会发着呆然后微微笑
# 17                                         接着紧紧闭上眼
# 18                                      又想那一年你温柔的脸
# 19                                          在我忘记之前
# 20                                        闭上眼睛还能看见
# 21                                          你离去的痕迹
# 22                                        在月光下一直找寻
# 23                                          那想念的身影
# 24                                     如果说分手是苦痛的起点
# 25                                   那在终点之前我愿意再爱一遍
# 26                                     想要对你说的不敢说的爱
# 27                                       会不会有人可以明白
# 28                                      我会发着呆然后忘记你
# 29                                         接着紧紧闭上眼
# ...                                            ...
# 2056                 你要离开 我知道很简单 你说依赖使我们的阻碍 ——《彩虹》
# 2057              20 雨下整夜 我的爱溢出就像雨水 院子落叶 跟我的思念厚厚一叠
# 2058                            你是我唯一想要的了解 ——《七里香》
# 2059             21 放在糖果旁的是我 很想回忆的甜 然而过滤了你和我 沦落而成美
# 2060           沉在盒子里的是你 给我的快乐 我很想记得可是我记不得 ——《半岛铁盒》
# 2061                                           励志篇
# 2062           1 对这个世界如果你有太多的抱怨 跌倒了就不该继续往前走 ——《稻香》
# 2063       2 活着 不是用来演一出糜烂的黑色 沉沦假象 你只会感到更加沮丧 ——《懦夫》
# 2064    3 默契无法伪造 我们同一种调调 凡事要自己主导 从不跟别人计较 ——《同一种调调》
# 2065  4 我只是卑微的小丑 翻几个跟斗 就等你拍一拍手 人群散了后 夜色多朦胧 月光也会跟着我
# 2066     我不是孤独的小丑 你笑了之后 不需要记得我 灯熄的时候 满天的星空 最明亮的是寂寞
# 2067                                      ——《乔克叔叔》
# 2068                         5 该不该搁下重重的壳 寻找到底哪里有蓝天
# 2069                 小小的天有大大的梦想 重重的壳有着轻轻的仰望 ——《蜗牛》
# 2070                             6 梦的边陲 风吹不灭 从不感疲惫
# 2071                      我态度坚决 面朝北 平地一声雷 ——《千山万水》
# 2072      7 这生命 对每个人 都不公平 也没道理 只能扑向 泥泞迎向 那阵骤雨 由不得你
# 2073            如果生命 对每个人 都不公平 那就让我 带着孤寂 继续前进 直到光明
# 2074             我只有一种容貌 我就是永远不会倒 我就算逆境环绕 我面对也要带着笑
# 2075                             我生命再怎么粗糙 我都要活的很骄傲
# 2076                    活着如果只是不甘寂寞的喧嚣 那就咆哮吧 ——《逆鳞》
# 2077          8 笑我得来不费功夫 别人已经包围了路 但我选择了沙漠 因为我取名叫自负
# 2078                    我告诉你做自己谁也别做 最大的敌人就是那内心中的自己
# 2079                            因为我选择了正视自己 ——《红磨坊》
# 2080                                           亲情篇
# 2081                       1 妈妈的辛苦不让你看见 温暖的食谱在他心里面
# 2082                                   听妈妈的话 别让她受伤
# 2083             美丽的白发 幸福总发芽 天使的魔法 温暖中慈祥 ——《听妈妈的话》
# 2084                      2 外婆她的期待 慢慢变成无奈 大人们始终不明白
# 2085                    外婆她的无奈 无法期待 只有爱才能明白 ——《外婆》
#
# [2086 rows x 1 columns]
